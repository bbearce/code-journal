# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Lab: Creating Custom Layers and Models**
#
# ###### Estimated time needed:  30 minutes
#
# In this lab, you will learn to create custom layers and integrate them into a Keras model. You will compile, train, and evaluate the model.
#
# ##### Learning objectives
#
# By the end of this lab, you will:
# - Create custom layers and integrate them into a Keras model
# - Compile, train, and evaluate the model
#
# ##### Prerequisites:
# - Basic understanding of Python and Keras.

# %% [markdown]
# #### Steps
#
# **Step 1: Install and Import libraries**
#
# Before you start, import the required libraries: TensorFlow and Keras. Keras is included within TensorFlow as `tensorflow.keras`.

# %%
# !pip install tensorflow==2.16.2
# !pip install pydot graphviz
# Out:
# Looking in indexes: https://pypi.org/simple, https://packagecloud.io/github/git-lfs/pypi/simple
# Collecting tensorflow==2.16.2
#   Downloading tensorflow-2.16.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (590.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 MB 2.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: astunparse>=1.6.0 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorflow==2.16.2) (1.6.3)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorflow==2.16.2) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorflow==2.16.2) (4.15.0)
# Requirement already satisfied: keras>=3.0.0 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorflow==2.16.2) (3.12.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorflow==2.16.2) (1.14.1)
# Requirement already satisfied: setuptools in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorflow==2.16.2) (58.1.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorflow==2.16.2) (2.0.0)
# Collecting ml-dtypes~=0.3.1
#   Downloading ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 51.0 MB/s eta 0:00:0000:01
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorflow==2.16.2) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorflow==2.16.2) (1.60.0)
# Requirement already satisfied: flatbuffers>=23.5.26 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorflow==2.16.2) (25.9.23)
# Requirement already satisfied: packaging in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorflow==2.16.2) (23.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorflow==2.16.2) (2.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorflow==2.16.2) (1.26.4)
# Requirement already satisfied: six>=1.12.0 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorflow==2.16.2) (1.16.0)
# Collecting tensorboard<2.17,>=2.16
#   Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 78.1 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: termcolor>=1.1.0 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorflow==2.16.2) (2.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorflow==2.16.2) (0.35.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorflow==2.16.2) (4.25.8)
# Requirement already satisfied: libclang>=13.0.0 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorflow==2.16.2) (16.0.6)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorflow==2.16.2) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorflow==2.16.2) (3.15.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow==2.16.2) (0.42.0)
# Requirement already satisfied: optree in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow==2.16.2) (0.18.0)
# Requirement already satisfied: namex in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow==2.16.2) (0.0.7)
# Requirement already satisfied: rich in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow==2.16.2) (13.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (2023.7.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (1.26.18)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2) (3.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2) (3.5.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2) (0.7.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow==2.16.2) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow==2.16.2) (0.1.2)
# Installing collected packages: ml-dtypes, tensorboard, tensorflow
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.1
#     Uninstalling tensorboard-2.17.1:
#       Successfully uninstalled tensorboard-2.17.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.10.0
#     Uninstalling tensorflow-2.10.0:
#       Successfully uninstalled tensorflow-2.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-cpu 2.17.1 requires tensorboard<2.18,>=2.17, but you have tensorboard 2.16.2 which is incompatible.
# Successfully installed ml-dtypes-0.3.2 tensorboard-2.16.2 tensorflow-2.16.2
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/bin/python3.10 -m pip install --upgrade pip' command.
# Looking in indexes: https://pypi.org/simple, https://packagecloud.io/github/git-lfs/pypi/simple
# Collecting pydot
#   Downloading pydot-4.0.1-py3-none-any.whl (37 kB)
# Collecting graphviz
#   Downloading graphviz-0.21-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 KB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=3.1.0 in /home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/lib/python3.10/site-packages (from pydot) (3.1.1)
# Installing collected packages: pydot, graphviz
# Successfully installed graphviz-0.21 pydot-4.0.1
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/home/bbearce/.pyenv/versions/3.10.4/envs/venv3.10.4/bin/python3.10 -m pip install --upgrade pip' command.

# %% [markdown]
# #### After installing the libraries, restart the kernel and then run the cells below

# %%
import tensorflow as tf
from tensorflow.keras.layers import Layer
from tensorflow.keras.models import Sequential
# Out:
# 2026-03-14 18:53:51.334202: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-03-14 18:53:51.354192: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-03-14 18:53:51.354221: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-03-14 18:53:51.364681: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-03-14 18:53:52.463302: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# **Step 2: Define a custom layer**
#
# Define a custom dense layer with 32 units and ReLU activation.

# %%
class CustomDenseLayer(Layer):
    def __init__(self, units=32):
        super(CustomDenseLayer, self).__init__()
        self.units = units

    def build(self, input_shape):
        self.w = self.add_weight(shape=(input_shape[-1], self.units),
                                 initializer='random_normal',
                                 trainable=True)
        self.b = self.add_weight(shape=(self.units,),
                                 initializer='zeros',
                                 trainable=True)
    def call(self, inputs):
        return tf.nn.relu(tf.matmul(inputs, self.w) + self.b)

# %% [markdown]
# **Step 3: Integrate the custom layer into a model**
#
# Create a Keras model using the custom layer.

# %%
from tensorflow.keras.layers import Softmax

# Define the model with Softmax in the output layer
model = Sequential([
    CustomDenseLayer(32),
    CustomDenseLayer(10),  # Hidden layer with ReLU activation
    Softmax()              # Output layer with Softmax activation for multi-class classification
])

# %% [markdown]
# The **Softmax** activation function is used in the output layer for multi-class classification tasks, ensuring the model outputs probabilities that sum up to 1 for each class, which aligns with categorical cross-entropy as the loss function. This adjustment ensures the model is optimized correctly for multi-class classification.

# %% [markdown]
# **Step 4: Compile the model**
#
# Compile the model with the Adam optimizer and categorical cross-entropy loss.

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy')
print("Model summary before building:")
model.summary()

# Build the model to show parameters
model.build((1000, 20))
print("\nModel summary after building:")
model.summary()
# Out:
# Model summary before building:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ custom_dense_layer_10           │ ?                      │   0 (unbuilt) │
# │ (CustomDenseLayer)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ custom_dense_layer_11           │ ?                      │   0 (unbuilt) │
# │ (CustomDenseLayer)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ softmax_4 (Softmax)             │ ?                      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Model summary after building:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ custom_dense_layer_10           │ (1000, 32)             │           672 │
# │ (CustomDenseLayer)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ custom_dense_layer_11           │ (1000, 10)             │           330 │
# │ (CustomDenseLayer)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ softmax_4 (Softmax)             │ (1000, 10)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,002 (3.91 KB)
#  Trainable params: 1,002 (3.91 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Step 5: Train the model**
#
# Train the model on some example data. For this example, you will generate random data for training. In practice, use a real data set.

# %%
import numpy as np 

# Generate random data 
x_train = np.random.random((1000, 20)) 
y_train = np.random.randint(10, size=(1000, 1)) 

# Convert labels to categorical one-hot encoding 
y_train = tf.keras.utils.to_categorical(y_train, num_classes=10) 
model.fit(x_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.3028
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3023
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3021
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3014
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3007
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3000
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2998
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2987
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2978
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2974

# %% [markdown]
# **Step 6: Evaluate the model**
#
# Evaluate the model using test data to see its performance.
#
# For this example, you will generate random test data. In practice, use a real data set.

# %%
# Generate random test data 
x_test = np.random.random((200, 20)) 
y_test = np.random.randint(10, size=(200, 1)) 

# Convert labels to categorical one-hot encoding 
y_test = tf.keras.utils.to_categorical(y_test, num_classes=10) 

# Evaluate the model 
loss = model.evaluate(x_test, y_test) 
print(f'Test loss: {loss}')
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3070
# Test loss: 2.307004451751709

# %% [markdown]
# ### Exercises

# %% [markdown]
# #### Exercise 1: Visualize Model Architecture
#
# **Objective:** Visualize the architecture of the custom Keras model to understand its structure.
#
# **Instructions:**
# 1. Use the `plot_model` function from `tensorflow.keras.utils` to visualize the model architecture.
# 2. Save the plot as an image file.

# %%
tf.keras.utils.plot_model(model, to_file='model.png')
# tf.keras.utils.plot_model??
# tf.keras.utils.plot_model?

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
#
# from tensorflow.keras.utils import plot_model
#
# # Visualize the model architecture
# plot_model(model, to_file='model_architecture.png', show_shapes=True, show_layer_names=True)
#
#
#  ```
#
# </details>

# %% [markdown]
# #### Exercise 2: Add Dropout Layer
#
# **Objective:** Enhance the model by adding a Dropout layer to prevent overfitting.
#
# **Instructions:**
# 1. Add a Dropout layer between the custom dense layers.
# 2. Recompile the model and observe the impact on training.

# %%
from tensorflow.keras.layers import Dropout

model_added_dropout_layer = Sequential([
    CustomDenseLayer(32),
    Dropout(rate=0.5),
    CustomDenseLayer(10),  # Hidden layer with ReLU activation
    Softmax()              # Output layer with Softmax activation for multi-class classification
])

model_added_dropout_layer.compile(optimizer='adam', loss='categorical_crossentropy')
print("Model summary before building:")
model_added_dropout_layer.summary()

# Build the model to show parameters
model_added_dropout_layer.build((1000, 20))
print("\nModel summary after building:")
model_added_dropout_layer.summary()
# Out:
# Model summary before building:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ custom_dense_layer_12           │ ?                      │   0 (unbuilt) │
# │ (CustomDenseLayer)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ custom_dense_layer_13           │ ?                      │   0 (unbuilt) │
# │ (CustomDenseLayer)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ softmax_5 (Softmax)             │ ?                      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Model summary after building:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ custom_dense_layer_12           │ (1000, 32)             │           672 │
# │ (CustomDenseLayer)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (1000, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ custom_dense_layer_13           │ (1000, 10)             │           330 │
# │ (CustomDenseLayer)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ softmax_5 (Softmax)             │ (1000, 10)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,002 (3.91 KB)
#  Trainable params: 1,002 (3.91 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
#
# from tensorflow.keras.layers import Dropout
#
# # Modify the model to include a Dropout layer
# model = Sequential([
#     CustomDenseLayer(64),
#     Dropout(0.5),
#     CustomDenseLayer(10)
# ])
#
# # Recompile the model
# model.compile(optimizer='adam', loss='categorical_crossentropy')
#
# # Train the model again
# model.fit(x_train, y_train, epochs=10, batch_size=32)
#  ```
#
# </details>

# %% [markdown]
# #### Exercise 3: Adjust the Number of Units in Custom Layer
#
# **Objective:** Experiment with different numbers of units in the custom dense layer to observe the impact on performance.
#
# **Instructions:**
# 1. Change the number of units in the `CustomDenseLayer` to 128.
# 2. Recompile, train, and evaluate the model.

# %%
from tensorflow.keras.layers import Dropout

model_added_dropout_128_layer = Sequential([
    CustomDenseLayer(128),
    Dropout(rate=0.5),
    CustomDenseLayer(10),  # Hidden layer with ReLU activation
    Softmax()              # Output layer with Softmax activation for multi-class classification
])

model_added_dropout_128_layer.compile(optimizer='adam', loss='categorical_crossentropy')
print("Model summary before building:")
model_added_dropout_128_layer.summary()

# Build the model to show parameters
model_added_dropout_128_layer.build((1000, 20))
print("\nModel summary after building:")
model_added_dropout_128_layer.summary()

# Train
model_added_dropout_128_layer.fit(x_train, y_train, epochs=10, batch_size=32) 


# Evaluate the model 
loss = model_added_dropout_128_layer.evaluate(x_test, y_test) 
print(f'Test loss: {loss}')
# Out:
# Model summary before building:
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ custom_dense_layer_32           │ ?                      │   0 (unbuilt) │
# │ (CustomDenseLayer)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ custom_dense_layer_33           │ ?                      │   0 (unbuilt) │
# │ (CustomDenseLayer)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ softmax_15 (Softmax)            │ ?                      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Model summary after building:
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ custom_dense_layer_32           │ (1000, 128)            │         2,688 │
# │ (CustomDenseLayer)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (1000, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ custom_dense_layer_33           │ (1000, 10)             │         1,290 │
# │ (CustomDenseLayer)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ softmax_15 (Softmax)            │ (1000, 10)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,978 (15.54 KB)
#  Trainable params: 3,978 (15.54 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.3011
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3006
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2989
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2966
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2974
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2978
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2920
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2943
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2887
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2849
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2980
# Test loss: 2.298004388809204

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
#
# # Define a custom layer with 128 units
# class CustomDenseLayer(Layer):
#     def __init__(self, units=128):
#         super(CustomDenseLayer, self).__init__()
#         self.units = units
#
#     def build(self, input_shape):
#         self.w = self.add_weight(shape=(input_shape[-1], self.units),
#                                  initializer='random_normal',
#                                  trainable=True)
#         self.b = self.add_weight(shape=(self.units,),
#                                  initializer='zeros',
#                                  trainable=True)
#
#     def call(self, inputs):
#         return tf.nn.relu(tf.matmul(inputs, self.w) + self.b)
#
# # Integrate the new custom layer into a model
# model = Sequential([
#     CustomDenseLayer(128),
#     CustomDenseLayer(10)
# ])
#
# # Recompile the model
# model.compile(optimizer='adam', loss='categorical_crossentropy')
#
# # Train the model again
# model.fit(x_train, y_train, epochs=10, batch_size=32)
#  ```
#
# </details>

# %% [markdown]
# ### Summary
#
# By completing these exercises, students will:
#
# 1. Visualize the architecture of their custom Keras model.
# 2. Understand the impact of adding Dropout layers to prevent overfitting.
# 3. Experiment with different configurations of the custom dense layer to observe performance changes.

# %% [markdown]
# ## Conclusion
#
# Congratulations! You have successfully created and trained a custom layer in Keras. This lab exercise demonstrated how to extend Keras’s capabilities by creating custom layers and integrating them into a model.

# %%
Copyright © IBM Corporation. All rights reserved.
