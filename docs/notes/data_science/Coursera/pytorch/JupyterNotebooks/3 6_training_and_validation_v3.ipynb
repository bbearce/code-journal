# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# <h1>Linear regression: Training and Validation Data</h1>

# %% [markdown]
# <h2>Objective</h2><ul><li> How to use learning rate hyperparameter to improve your model result.  .</li></ul>

# %% [markdown]
# <h2>Table of Contents</h2>
# <p>In this lab, you will learn to select the best learning rate by using validation data.</p>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <font size="3">
#         1. <a href="#Make-Some-Data">Make Some Data</a><br>
#         2. <a href="#Create-a-Linear-Regression-Object-Data-Loader-and-Criterion-Function">Create a Linear Regression Object Data Loader and Criterion Function</a><br>
#         3. <a href="#Different-learning-rates-and-Data-Structures-to-Store-results-for-Different-Hyperparameters">Different learning rates and Data Structures to Store results for Different Hyperparameters</a><br>
#         4. <a href="#Train-different-modules-for-different-Hyperparameters">Train different modules for different Hyperparameters</a><br>
#         5. <a href="#View-Results">View Results</a><br>
#
# <p>Estimated Time Needed: <strong>30 min</strong></p>
# </font>
# </div>

# %% [markdown]
# <h2>Preparation</h2>

# %% [markdown]
# We'll need the following libraries and set the random seed.

# %%
# %%time
# %pip install numpy matplotlib
# %pip install torch==2.8.0+cpu torchvision==0.23.0+cpu torchaudio==2.8.0+cpu \
    --index-url https://download.pytorch.org/whl/cpu

# %%
# Import libraries we need for this lab, and set the random seed

from torch import nn
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch import nn,optim

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <!-- <h2 id="Makeup_Data">Make Some Data</h2> -->
# ## Make Some Data

# %% [markdown]
# First, we'll create some artificial data in a dataset class. The class will include the option to produce training data or validation data. The training data will include outliers.

# %%
torch.arange(-3, 3, 0.1).view(-1, 1)
# Out:
# tensor([[-3.0000e+00],
#         [-2.9000e+00],
#         [-2.8000e+00],
#         [-2.7000e+00],
#         [-2.6000e+00],
#         [-2.5000e+00],
#         [-2.4000e+00],
#         [-2.3000e+00],
#         [-2.2000e+00],
#         [-2.1000e+00],
#         [-2.0000e+00],
#         [-1.9000e+00],
#         [-1.8000e+00],
#         [-1.7000e+00],
#         [-1.6000e+00],
#         [-1.5000e+00],
#         [-1.4000e+00],
#         [-1.3000e+00],
#         [-1.2000e+00],
#         [-1.1000e+00],
#         [-1.0000e+00],
#         [-9.0000e-01],
#         [-8.0000e-01],
#         [-7.0000e-01],
#         [-6.0000e-01],
#         [-5.0000e-01],
#         [-4.0000e-01],
#         [-3.0000e-01],
#         [-2.0000e-01],
#         [-1.0000e-01],
#         [-2.3842e-08],
#         [ 1.0000e-01],
#         [ 2.0000e-01],
#         [ 3.0000e-01],
#         [ 4.0000e-01],
#         [ 5.0000e-01],
#         [ 6.0000e-01],
#         [ 7.0000e-01],
#         [ 8.0000e-01],
#         [ 9.0000e-01],
#         [ 1.0000e+00],
#         [ 1.1000e+00],
#         [ 1.2000e+00],
#         [ 1.3000e+00],
#         [ 1.4000e+00],
#         [ 1.5000e+00],
#         [ 1.6000e+00],
#         [ 1.7000e+00],
#         [ 1.8000e+00],
#         [ 1.9000e+00],
#         [ 2.0000e+00],
#         [ 2.1000e+00],
#         [ 2.2000e+00],
#         [ 2.3000e+00],
#         [ 2.4000e+00],
#         [ 2.5000e+00],
#         [ 2.6000e+00],
#         [ 2.7000e+00],
#         [ 2.8000e+00],
#         [ 2.9000e+00]])

# %%
# Create Data class

from torch.utils.data import Dataset, DataLoader

class Data(Dataset):
    
    # Constructor
    def __init__(self, train = True):
            self.x = torch.arange(-3, 3, 0.1).view(-1, 1)
            self.f = -3 * self.x + 1
            self.y = self.f + 0.1 * torch.randn(self.x.size())
            self.len = self.x.shape[0]
            
            #outliers 
            if train == True:
                self.y[0] = 0
                self.y[50:55] = 20
            else:
                pass
      
    # Getter
    def __getitem__(self, index):    
        return self.x[index], self.y[index]
    
    # Get Length
    def __len__(self):
        return self.len

# %% [markdown]
# Create two objects: one that contains training data and a second that contains validation data. Assume that the training data has the outliers.

# %%
# Create training dataset and validation dataset

train_data = Data()
val_data = Data(train = False)

# %% [markdown]
# Overlay the training points in red over the function that generated the data. Notice the outliers at x=-3 and around x=2:

# %%
# Plot out training points

plt.plot(train_data.x.numpy(), train_data.y.numpy(), 'xr',label="training data ")
plt.plot(train_data.x.numpy(), train_data.f.numpy(),label="true function  ")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <!-- <h2 id="LR_Loader_Cost">Create a Linear Regression Object,  Data Loader, and Criterion Function</h2> -->
# ## Create a Linear Regression Object Data Loader and Criterion Function

# %%
# Create Linear Regression Class

from torch import nn

class linear_regression(nn.Module):
    
    # Constructor
    def __init__(self, input_size, output_size):
        super(linear_regression, self).__init__()
        self.linear = nn.Linear(input_size, output_size)
    
    # Prediction function
    def forward(self, x):
        yhat = self.linear(x)
        return yhat

# %% [markdown]
# Create the criterion function and a <code>DataLoader</code> object:

# %%
# Create MSELoss function and DataLoader

criterion = nn.MSELoss()
trainloader = DataLoader(dataset = train_data, batch_size = 1)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <!-- <h2 id="LR_Hyper">Different learning rates and Data Structures to Store results for different Hyperparameters</h2> -->
# ## Different learning rates and Data Structures to Store results for Different Hyperparameters

# %% [markdown]
# Create a list with different learning rates and a tensor (can be a list) for the training and validating cost/total loss. Include the list MODELS, which stores the training model for every value of the learning rate.

# %%
# Create Learning Rate list, the error lists and the MODELS list

learning_rates=[0.0001, 0.001, 0.01, 0.1]

train_error=torch.zeros(len(learning_rates))
validation_error=torch.zeros(len(learning_rates))

MODELS=[]

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <!-- <h2 id="Model">Train different models  for different Hyperparameters</h2> -->
# ## Train different modules for different Hyperparameters

# %% [markdown]
# Try different values of learning rates, perform stochastic gradient descent, and save the results on the training data and validation data. Finally, save each model in a list.

# %%
# Define the train model function and train the model

def train_model_with_lr (iter, lr_list):
    
    # iterate through different learning rates 
    for i, lr in enumerate(lr_list):
        model = linear_regression(1, 1)
        optimizer = optim.SGD(model.parameters(), lr = lr)
        for epoch in range(iter):
            for x, y in trainloader:
                yhat = model(x)
                loss = criterion(yhat, y)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
        # train data
        Yhat = model(train_data.x)
        train_loss = criterion(Yhat, train_data.y)
        train_error[i] = train_loss.item()
    
        # validation data
        Yhat = model(val_data.x)
        val_loss = criterion(Yhat, val_data.y)
        validation_error[i] = val_loss.item()
        MODELS.append(model)

train_model_with_lr(10, learning_rates)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <!-- <h2 id="Result">View the Results</h2>
#  -->
# ## View Results

# %% [markdown]
# Plot the training loss and validation loss for each learning rate:

# %%
# Plot the training loss and validation loss

plt.semilogx(np.array(learning_rates), train_error.numpy(), label = 'training loss/total Loss')
plt.semilogx(np.array(learning_rates), validation_error.numpy(), label = 'validation cost/total Loss')
plt.ylabel('Cost\ Total Loss')
plt.xlabel('learning rate')
plt.legend()
plt.show()

# %% [markdown]
# Produce a prediction by using the validation data for each model:

# %%
# Plot the predictions

i = 0
for model, learning_rate in zip(MODELS, learning_rates):
    yhat = model(val_data.x)
    plt.plot(val_data.x.numpy(), yhat.detach().numpy(), label = 'lr:' + str(learning_rate))
    print(i, yhat.detach().numpy()[0:3])
    i+=1
plt.plot(val_data.x.numpy(), val_data.f.numpy(), 'or', label = 'validation data')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# 0 [[3.0378125]
#  [2.9460537]
#  [2.8542945]]
# 1 [[5.583069]
#  [5.466747]
#  [5.350425]]
# 2 [[6.5560083]
#  [6.422782 ]
#  [6.2895555]]
# 3 [[13.957063]
#  [13.539299]
#  [13.121535]]

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h3>Practice</h3>

# %% [markdown]
# The object <code>good_model</code> is the best performing model. Use the train loader to get the data samples x and y. Produce an estimate for <code>yhat</code> and print it out for every sample in a for a loop. Compare it to the actual prediction <code>y</code>.

# %%
good_model = MODELS[np.argmin(validation_error)]

#Type your code here: 
for x, y in trainloader:
    yhat = model(x)
    print(f"x {x}, y {y}, yhat {yhat}")
# Out:
# x tensor([[-3.]]), y tensor([[0.]]), yhat tensor([[13.9571]], grad_fn=<AddmmBackward0>)
# x tensor([[-2.9000]]), y tensor([[9.6427]]), yhat tensor([[13.5393]], grad_fn=<AddmmBackward0>)
# x tensor([[-2.8000]]), y tensor([[9.3600]]), yhat tensor([[13.1215]], grad_fn=<AddmmBackward0>)
# x tensor([[-2.7000]]), y tensor([[9.0427]]), yhat tensor([[12.7038]], grad_fn=<AddmmBackward0>)
# x tensor([[-2.6000]]), y tensor([[8.7974]]), yhat tensor([[12.2860]], grad_fn=<AddmmBackward0>)
# x tensor([[-2.5000]]), y tensor([[8.4202]]), yhat tensor([[11.8682]], grad_fn=<AddmmBackward0>)
# x tensor([[-2.4000]]), y tensor([[8.1806]]), yhat tensor([[11.4505]], grad_fn=<AddmmBackward0>)
# x tensor([[-2.3000]]), y tensor([[7.8797]]), yhat tensor([[11.0327]], grad_fn=<AddmmBackward0>)
# x tensor([[-2.2000]]), y tensor([[7.5452]]), yhat tensor([[10.6150]], grad_fn=<AddmmBackward0>)
# x tensor([[-2.1000]]), y tensor([[7.2030]]), yhat tensor([[10.1972]], grad_fn=<AddmmBackward0>)
# x tensor([[-2.]]), y tensor([[6.9023]]), yhat tensor([[9.7794]], grad_fn=<AddmmBackward0>)
# x tensor([[-1.9000]]), y tensor([[6.8534]]), yhat tensor([[9.3617]], grad_fn=<AddmmBackward0>)
# x tensor([[-1.8000]]), y tensor([[6.3018]]), yhat tensor([[8.9439]], grad_fn=<AddmmBackward0>)
# x tensor([[-1.7000]]), y tensor([[6.1135]]), yhat tensor([[8.5261]], grad_fn=<AddmmBackward0>)
# x tensor([[-1.6000]]), y tensor([[6.0024]]), yhat tensor([[8.1084]], grad_fn=<AddmmBackward0>)
# x tensor([[-1.5000]]), y tensor([[5.4639]]), yhat tensor([[7.6906]], grad_fn=<AddmmBackward0>)
# x tensor([[-1.4000]]), y tensor([[5.1686]]), yhat tensor([[7.2728]], grad_fn=<AddmmBackward0>)
# x tensor([[-1.3000]]), y tensor([[4.8629]]), yhat tensor([[6.8551]], grad_fn=<AddmmBackward0>)
# x tensor([[-1.2000]]), y tensor([[4.3903]]), yhat tensor([[6.4373]], grad_fn=<AddmmBackward0>)
# x tensor([[-1.1000]]), y tensor([[4.2361]]), yhat tensor([[6.0196]], grad_fn=<AddmmBackward0>)
# x tensor([[-1.]]), y tensor([[4.0185]]), yhat tensor([[5.6018]], grad_fn=<AddmmBackward0>)
# x tensor([[-0.9000]]), y tensor([[3.5652]]), yhat tensor([[5.1840]], grad_fn=<AddmmBackward0>)
# x tensor([[-0.8000]]), y tensor([[3.6663]]), yhat tensor([[4.7663]], grad_fn=<AddmmBackward0>)
# x tensor([[-0.7000]]), y tensor([[3.0453]]), yhat tensor([[4.3485]], grad_fn=<AddmmBackward0>)
# x tensor([[-0.6000]]), y tensor([[2.8462]]), yhat tensor([[3.9307]], grad_fn=<AddmmBackward0>)
# x tensor([[-0.5000]]), y tensor([[2.5414]]), yhat tensor([[3.5130]], grad_fn=<AddmmBackward0>)
# x tensor([[-0.4000]]), y tensor([[2.2903]]), yhat tensor([[3.0952]], grad_fn=<AddmmBackward0>)
# x tensor([[-0.3000]]), y tensor([[1.9584]]), yhat tensor([[2.6774]], grad_fn=<AddmmBackward0>)
# x tensor([[-0.2000]]), y tensor([[1.4295]]), yhat tensor([[2.2597]], grad_fn=<AddmmBackward0>)
# x tensor([[-0.1000]]), y tensor([[1.2590]]), yhat tensor([[1.8419]], grad_fn=<AddmmBackward0>)
# x tensor([[-2.3842e-08]]), y tensor([[0.9624]]), yhat tensor([[1.4241]], grad_fn=<AddmmBackward0>)
# x tensor([[0.1000]]), y tensor([[0.5696]]), yhat tensor([[1.0064]], grad_fn=<AddmmBackward0>)
# x tensor([[0.2000]]), y tensor([[0.6011]]), yhat tensor([[0.5886]], grad_fn=<AddmmBackward0>)
# x tensor([[0.3000]]), y tensor([[0.0829]]), yhat tensor([[0.1709]], grad_fn=<AddmmBackward0>)
# x tensor([[0.4000]]), y tensor([[-0.1261]]), yhat tensor([[-0.2469]], grad_fn=<AddmmBackward0>)
# x tensor([[0.5000]]), y tensor([[-0.7247]]), yhat tensor([[-0.6647]], grad_fn=<AddmmBackward0>)
# x tensor([[0.6000]]), y tensor([[-0.9285]]), yhat tensor([[-1.0824]], grad_fn=<AddmmBackward0>)
# x tensor([[0.7000]]), y tensor([[-1.0903]]), yhat tensor([[-1.5002]], grad_fn=<AddmmBackward0>)
# x tensor([[0.8000]]), y tensor([[-1.6223]]), yhat tensor([[-1.9180]], grad_fn=<AddmmBackward0>)
# x tensor([[0.9000]]), y tensor([[-1.7772]]), yhat tensor([[-2.3357]], grad_fn=<AddmmBackward0>)
# x tensor([[1.]]), y tensor([[-2.1201]]), yhat tensor([[-2.7535]], grad_fn=<AddmmBackward0>)
# x tensor([[1.1000]]), y tensor([[-2.3021]]), yhat tensor([[-3.1713]], grad_fn=<AddmmBackward0>)
# x tensor([[1.2000]]), y tensor([[-2.6829]]), yhat tensor([[-3.5890]], grad_fn=<AddmmBackward0>)
# x tensor([[1.3000]]), y tensor([[-2.8515]]), yhat tensor([[-4.0068]], grad_fn=<AddmmBackward0>)
# x tensor([[1.4000]]), y tensor([[-3.0862]]), yhat tensor([[-4.4245]], grad_fn=<AddmmBackward0>)
# x tensor([[1.5000]]), y tensor([[-3.4186]]), yhat tensor([[-4.8423]], grad_fn=<AddmmBackward0>)
# x tensor([[1.6000]]), y tensor([[-3.7217]]), yhat tensor([[-5.2601]], grad_fn=<AddmmBackward0>)
# x tensor([[1.7000]]), y tensor([[-4.0163]]), yhat tensor([[-5.6778]], grad_fn=<AddmmBackward0>)
# x tensor([[1.8000]]), y tensor([[-4.3658]]), yhat tensor([[-6.0956]], grad_fn=<AddmmBackward0>)
# x tensor([[1.9000]]), y tensor([[-4.8640]]), yhat tensor([[-6.5134]], grad_fn=<AddmmBackward0>)
# x tensor([[2.]]), y tensor([[20.]]), yhat tensor([[-6.9311]], grad_fn=<AddmmBackward0>)
# x tensor([[2.1000]]), y tensor([[20.]]), yhat tensor([[-7.3489]], grad_fn=<AddmmBackward0>)
# x tensor([[2.2000]]), y tensor([[20.]]), yhat tensor([[-7.7667]], grad_fn=<AddmmBackward0>)
# x tensor([[2.3000]]), y tensor([[20.]]), yhat tensor([[-8.1844]], grad_fn=<AddmmBackward0>)
# x tensor([[2.4000]]), y tensor([[20.]]), yhat tensor([[-8.6022]], grad_fn=<AddmmBackward0>)
# x tensor([[2.5000]]), y tensor([[-6.3696]]), yhat tensor([[-9.0199]], grad_fn=<AddmmBackward0>)
# x tensor([[2.6000]]), y tensor([[-6.6803]]), yhat tensor([[-9.4377]], grad_fn=<AddmmBackward0>)
# x tensor([[2.7000]]), y tensor([[-7.0896]]), yhat tensor([[-9.8555]], grad_fn=<AddmmBackward0>)
# x tensor([[2.8000]]), y tensor([[-7.5519]]), yhat tensor([[-10.2732]], grad_fn=<AddmmBackward0>)
# x tensor([[2.9000]]), y tensor([[-7.6057]]), yhat tensor([[-10.6910]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!--
# for x, y in trainloader:
#     print("yhat= ", model(x),"y", y)
# -->

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/registration/stepone?utm_source=skills_network&utm_content=in_lab_content_link&utm_id=Lab-IBMDeveloperSkillsNetwork-DL0110EN-SkillsNetwork&context=cpdaas&apps=data_science_experience%2Cwatson_machine_learning"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0110EN-SkillsNetwork/Template/module%201/images/Watson_Studio.png"></a>

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# Other contributors: <a href="https://www.linkedin.com/in/michelleccarey/">Michelle Carey</a>, <a href="https://www.linkedin.com/in/jiahui-mavis-zhou-a4537814a/">Mavis Zhou</a>

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-09-23  | 2.0  | Shubham  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
# -->

# %% [markdown]
# <hr>

# %% [markdown]
# ## <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
